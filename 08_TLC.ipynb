# %% [markdown]
# # Corso di Probabilità e Statistica - Teorema del limite centrale
#
# In questo capitolo discutiamo del teorema del limite centrale

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
# usiamo caratteri leggibili!
plt.rcParams.update({'font.size': 18})

# %% [markdown]
# **Distribuzione uniforme**

# %%
N=10 #numero di variabili da sommare
NR=10000 #numero di realizzazioni

# %%
S=np.zeros(NR) # inizializzazione 
# vettore di NR zeri in cui sommiamo N numeri casuali
# Quindi S sarà un vettore con NR numeri in cui ognuno di questo è la somma di
# N numeri random
for i in range(NR):
    S[i]=S[i]+np.sum(np.random.rand(N))/N

# %%
# Calcoliamo media e varianza
mu_S=np.mean(S)
sigma2_S=np.std(S)
# CLT
mu=0.5
sigma=np.sqrt(1./(12*N))
mu_S,sigma2_S,mu,sigma
# Out:
# (0.5007367983875761, 0.09079324931063025, 0.5, 0.09128709291752768)

# %%
# Istogramma
plt.hist(S,bins=60,density=True,label="S")
# Distribuzione teorica CLT
xmin=np.min(S)
xmax=np.max(S)
x = np.linspace(xmin,xmax,101)
g=stats.norm(loc=mu, scale=sigma) 
plt.plot(x, g.pdf(x), label="CLT")
plt.legend()
plt.xlabel("S")
plt.ylabel("p(S)")
plt.show()

# %% [markdown]
# **Esercizio**
#
# Ripetere il calcolo con una distribuzione di variabili esponenziale.
#
# $$ p(x | \lambda) = \lambda \exp(-\lambda x) $$
#
# A parità di N esplorare l'effetto del parametro $\lambda$ sulla convergenza della distribzione della media verso la Gaussiana.

# %%
N=2
NR=1000

# %%
S=np.zeros(NR)
l0=.1
for i in range(NR):
    S[i]=S[i]+np.sum(np.random.exponential(l0,N))/N

# %%
# Calcoliamo media e varianza
mu_S=np.mean(S)
sigma2_S=np.std(S)
# CLT
mu=l0
sigma=np.sqrt(l0**2/N)
mu_S,sigma2_S,mu,sigma
# Out:
# (0.10202099999214215, 0.06957784456004362, 0.1, 0.07071067811865477)

# %%
# Istogramma
plt.hist(S,bins=60,density=True,label="S")
# Distribuzione teorica CLT
xmin=np.min(S)
xmax=np.max(S)
x = np.linspace(xmin,xmax,101)
g=stats.norm(loc=mu, scale=sigma) 
plt.plot(x, g.pdf(x), label="CLT")
plt.legend()
plt.xlabel("S")
plt.ylabel("p(S)")
plt.show()

# %% [markdown]
# **Distribuzione di Levy**
#
# Consideriamo ora la somma di variabili distribuite con una distribuzione a legge di potenza
#
# $$ p(x) = x^{-a} \; \; x>1$$
#
# se l'esponente $a < 2$ la distribuzione della somma non converge più alla Gaussiana ma alla distribuzione di Levy.

# %%
N=100 #numero di variabili da sommare
NR=100000 #numero di realizzazioni
a=1.5 #esponente

# %%
S=np.zeros(NR) # inizializzazione
for i in range(NR):
    x =np.random.rand(N)
    y=(1-x)**(1/(1-a))
    S[i]=S[i]+np.sum(y)/N

# %%
# Calcoliamo media e varianza
mu_S=np.mean(S)
sigma_S=np.std(S)

# %%
# Istogramma
plt.hist(S,bins=1000,density=True,label="S", log=True)
# Distribuzione teorica CLT
xmin=np.min(S)
xmax=np.max(S)
x = np.linspace(xmin,xmax,101)
g=stats.norm(loc=mu_S, scale=sigma_S) 
plt.plot(x, g.pdf(x), label="CLT")
plt.legend()
plt.xlabel("S")
plt.ylabel("p(S)")
plt.show()

# %%
# calcoliamo il logaritmo di S
logS=np.log(S)

# %%
# Istogramma del log in scala log
plt.hist(logS,bins=1000,density=True,label="S", log=True)
plt.legend()
plt.xlabel("log(S)")
plt.ylabel("p(S)")
plt.show()
